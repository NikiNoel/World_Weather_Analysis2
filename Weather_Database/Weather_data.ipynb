# %%
# Import dependencies (6.1.4)
import pandas as pd
import numpy as np
import random as random
import matplotlib as plt
import requests
import time
from datetime import datetime

# Import API key
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Generate a set of random Lats and Longs (6.1.4)
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# Add Latitudes and Longitudes to a list
coordinates = list(lats_lngs)

# %%
# Generate Random World Cities (6.1.5)
# Use citipy to module to determine city for each latitude and longitude.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Understandong API's
# Add weather API to config.py, import request to list of dependencies
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Check to see if request.get worked
   # print(requests.get(city_url).json())
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Add current_description variable
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": current_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | tessalit
# Processing Record 3 of Set 1 | vermillion
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | superior
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | kaeo
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | deputatskiy
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | pokhara
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | caravelas
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | tomatlan
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | krasnoselkup
# Processing Record 28 of Set 1 | la ronge
# Processing Record 29 of Set 1 | lasa
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | coahuayana
# Processing Record 32 of Set 1 | hay river
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | fez
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | sorland
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | the valley
# Processing Record 43 of Set 1 | punta alta
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | grand gaube
# Processing Record 47 of Set 1 | hovd
# Processing Record 48 of Set 1 | mehamn
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | turukhansk
# Processing Record 1 of Set 2 | chifeng
# Processing Record 2 of Set 2 | coolum beach
# Processing Record 3 of Set 2 | altamira
# Processing Record 4 of Set 2 | volsk
# Processing Record 5 of Set 2 | metro
# Processing Record 6 of Set 2 | adrar
# Processing Record 7 of Set 2 | praia da vitoria
# Processing Record 8 of Set 2 | brae
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | guaratuba
# Processing Record 13 of Set 2 | okandja
# City not found. Skipping...
# Processing Record 14 of Set 2 | poyarkovo
# Processing Record 15 of Set 2 | wanning
# Processing Record 16 of Set 2 | mananara
# Processing Record 17 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 2 | haines junction
# Processing Record 19 of Set 2 | syamzha
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | biloela
# Processing Record 22 of Set 2 | vao
# Processing Record 23 of Set 2 | moree
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | alyangula
# Processing Record 26 of Set 2 | sao felix do xingu
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | xuanzhou
# Processing Record 29 of Set 2 | hami
# Processing Record 30 of Set 2 | bermeo
# Processing Record 31 of Set 2 | santa cruz
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | juegang
# Processing Record 35 of Set 2 | sergeyevka
# Processing Record 36 of Set 2 | inhambane
# Processing Record 37 of Set 2 | la paz
# Processing Record 38 of Set 2 | rakkestad
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | angoche
# Processing Record 41 of Set 2 | manaus
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | korla
# Processing Record 44 of Set 2 | beidao
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | longjiang
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | sioux lookout
# Processing Record 1 of Set 3 | anadyr
# Processing Record 2 of Set 3 | sangar
# Processing Record 3 of Set 3 | manoel urbano
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 3 | novoagansk
# Processing Record 7 of Set 3 | beloha
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | tromso
# Processing Record 10 of Set 3 | ketchikan
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | broken hill
# Processing Record 13 of Set 3 | nemuro
# Processing Record 14 of Set 3 | riyadh
# Processing Record 15 of Set 3 | ushuaia
# Processing Record 16 of Set 3 | dikson
# Processing Record 17 of Set 3 | mount darwin
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 3 | nantucket
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | klaksvik
# Processing Record 26 of Set 3 | cortez
# Processing Record 27 of Set 3 | emba
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | srikakulam
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 3 | bonavista
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | saint-joseph
# Processing Record 38 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 3 | canavieiras
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | praya
# Processing Record 42 of Set 3 | ulladulla
# Processing Record 43 of Set 3 | aripuana
# Processing Record 44 of Set 3 | cartagena
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | buala
# Processing Record 47 of Set 3 | gizo
# Processing Record 48 of Set 3 | castro
# Processing Record 49 of Set 3 | tura
# Processing Record 50 of Set 3 | bredasdorp
# Processing Record 1 of Set 4 | chuguyevka
# Processing Record 2 of Set 4 | tartagal
# Processing Record 3 of Set 4 | nesna
# Processing Record 4 of Set 4 | morwell
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | labuhan
# Processing Record 7 of Set 4 | rockhampton
# Processing Record 8 of Set 4 | konakovo
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | padang
# Processing Record 14 of Set 4 | baoding
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | plettenberg bay
# Processing Record 17 of Set 4 | sorkjosen
# Processing Record 18 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 4 | chapais
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | opuwo
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | lakkion
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | batagay
# Processing Record 27 of Set 4 | abeche
# Processing Record 28 of Set 4 | khorixas
# Processing Record 29 of Set 4 | lakselv
# Processing Record 30 of Set 4 | lokosovo
# Processing Record 31 of Set 4 | cascavel
# Processing Record 32 of Set 4 | banda aceh
# Processing Record 33 of Set 4 | christchurch
# Processing Record 34 of Set 4 | akureyri
# Processing Record 35 of Set 4 | marienburg
# Processing Record 36 of Set 4 | sinop
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | wexford
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | nioro
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | byron bay
# Processing Record 43 of Set 4 | nelson bay
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | praia
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | chengde
# Processing Record 49 of Set 4 | moose factory
# Processing Record 50 of Set 4 | ca mau
# Processing Record 1 of Set 5 | mashhad
# Processing Record 2 of Set 5 | shubarshi
# Processing Record 3 of Set 5 | bac lieu
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | mount isa
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | corn island
# Processing Record 9 of Set 5 | karema
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | camocim
# Processing Record 13 of Set 5 | nadym
# Processing Record 14 of Set 5 | samarai
# Processing Record 15 of Set 5 | shenzhen
# Processing Record 16 of Set 5 | boa vista
# Processing Record 17 of Set 5 | arona
# Processing Record 18 of Set 5 | mackay
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | chisindia
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | dibulla
# Processing Record 24 of Set 5 | kalmunai
# Processing Record 25 of Set 5 | yingcheng
# Processing Record 26 of Set 5 | yuancheng
# Processing Record 27 of Set 5 | buraydah
# Processing Record 28 of Set 5 | karratha
# Processing Record 29 of Set 5 | jacareacanga
# Processing Record 30 of Set 5 | ravar
# Processing Record 31 of Set 5 | georgetown
# Processing Record 32 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 33 of Set 5 | lyndon
# Processing Record 34 of Set 5 | shillong
# Processing Record 35 of Set 5 | lerwick
# Processing Record 36 of Set 5 | husavik
# Processing Record 37 of Set 5 | aklavik
# Processing Record 38 of Set 5 | bambanglipuro
# Processing Record 39 of Set 5 | folldal
# Processing Record 40 of Set 5 | broome
# Processing Record 41 of Set 5 | cacoal
# Processing Record 42 of Set 5 | mwinilunga
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | khatanga
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | helena
# Processing Record 48 of Set 5 | wenling
# Processing Record 49 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 5 | todos santos
# Processing Record 1 of Set 6 | crib point
# Processing Record 2 of Set 6 | marawi
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | charcas
# Processing Record 5 of Set 6 | pychas
# Processing Record 6 of Set 6 | bilma
# Processing Record 7 of Set 6 | kidal
# Processing Record 8 of Set 6 | kattivakkam
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | bow island
# Processing Record 11 of Set 6 | lippstadt
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | petatlan
# Processing Record 14 of Set 6 | dwarka
# Processing Record 15 of Set 6 | manali
# Processing Record 16 of Set 6 | geraldton
# Processing Record 17 of Set 6 | midland
# Processing Record 18 of Set 6 | santa rosa
# Processing Record 19 of Set 6 | itoman
# Processing Record 20 of Set 6 | north bend
# Processing Record 21 of Set 6 | port macquarie
# Processing Record 22 of Set 6 | adzhamka
# Processing Record 23 of Set 6 | alugan
# Processing Record 24 of Set 6 | waconia
# Processing Record 25 of Set 6 | cap malheureux
# Processing Record 26 of Set 6 | trat
# Processing Record 27 of Set 6 | waipawa
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | muscat
# Processing Record 30 of Set 6 | san rafael
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | talara
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | alekseyevka
# Processing Record 35 of Set 6 | leningradskiy
# Processing Record 36 of Set 6 | djenne
# Processing Record 37 of Set 6 | duz
# City not found. Skipping...
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 6 | andenes
# Processing Record 41 of Set 6 | henties bay
# Processing Record 42 of Set 6 | letka
# Processing Record 43 of Set 6 | concordia
# Processing Record 44 of Set 6 | san jose del palmar
# Processing Record 45 of Set 6 | chapada dos guimaraes
# Processing Record 46 of Set 6 | langarud
# Processing Record 47 of Set 6 | maragogi
# Processing Record 48 of Set 6 | kwekwe
# Processing Record 49 of Set 6 | pulandian
# Processing Record 50 of Set 6 | pyapon
# Processing Record 1 of Set 7 | doaba
# Processing Record 2 of Set 7 | ahuimanu
# Processing Record 3 of Set 7 | mayo
# Processing Record 4 of Set 7 | kashira
# Processing Record 5 of Set 7 | ascension
# Processing Record 6 of Set 7 | hun
# Processing Record 7 of Set 7 | lahat
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | honningsvag
# Processing Record 10 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 11 of Set 7 | hofn
# Processing Record 12 of Set 7 | rio gallegos
# Processing Record 13 of Set 7 | aktau
# Processing Record 14 of Set 7 | lashio
# Processing Record 15 of Set 7 | lebu
# Processing Record 16 of Set 7 | beringovskiy
# Processing Record 17 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 7 | hambantota
# Processing Record 19 of Set 7 | kungurtug
# Processing Record 20 of Set 7 | lata
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | kudahuvadhoo
# Processing Record 23 of Set 7 | envira
# Processing Record 24 of Set 7 | comodoro rivadavia
# Processing Record 25 of Set 7 | lavrentiya
# Processing Record 26 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 7 | stornoway
# Processing Record 28 of Set 7 | nouadhibou
# Processing Record 29 of Set 7 | mancio lima
# Processing Record 30 of Set 7 | santa vitoria do palmar
# Processing Record 31 of Set 7 | namibe
# Processing Record 32 of Set 7 | guiren
# Processing Record 33 of Set 7 | tandil
# Processing Record 34 of Set 7 | canete
# Processing Record 35 of Set 7 | olenino
# Processing Record 36 of Set 7 | along
# Processing Record 37 of Set 7 | novyy urengoy
# Processing Record 38 of Set 7 | ust-maya
# Processing Record 39 of Set 7 | kavaratti
# Processing Record 40 of Set 7 | orebro
# Processing Record 41 of Set 7 | urla
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | nago
# Processing Record 44 of Set 7 | mananjary
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | vrangel
# Processing Record 47 of Set 7 | yamada
# Processing Record 48 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 7 | barao de melgaco
# Processing Record 50 of Set 7 | riverton
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | olafsvik
# Processing Record 3 of Set 8 | raga
# Processing Record 4 of Set 8 | mogadishu
# Processing Record 5 of Set 8 | keflavik
# Processing Record 6 of Set 8 | senmonorom
# City not found. Skipping...
# Processing Record 7 of Set 8 | mattru
# Processing Record 8 of Set 8 | severo-kurilsk
# Processing Record 9 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 8 | sydney mines
# Processing Record 11 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 8 | saint-francois
# Processing Record 13 of Set 8 | roebourne
# Processing Record 14 of Set 8 | gwadar
# Processing Record 15 of Set 8 | cabo san lucas
# Processing Record 16 of Set 8 | puerto carreno
# Processing Record 17 of Set 8 | tiksi
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | atar
# Processing Record 20 of Set 8 | naron
# Processing Record 21 of Set 8 | gariaband
# Processing Record 22 of Set 8 | necochea
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | alandi
# Processing Record 25 of Set 8 | burica
# City not found. Skipping...
# Processing Record 26 of Set 8 | bar harbor
# Processing Record 27 of Set 8 | kolokani
# Processing Record 28 of Set 8 | crotone
# Processing Record 29 of Set 8 | rio grande
# Processing Record 30 of Set 8 | haileybury
# Processing Record 31 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 8 | emerald
# Processing Record 33 of Set 8 | asau
# Processing Record 34 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 35 of Set 8 | tupaciguara
# Processing Record 36 of Set 8 | san carlos de bariloche
# Processing Record 37 of Set 8 | aguadilla
# Processing Record 38 of Set 8 | katsuura
# Processing Record 39 of Set 8 | tigil
# Processing Record 40 of Set 8 | pisco
# Processing Record 41 of Set 8 | batagay-alyta
# Processing Record 42 of Set 8 | khandyga
# Processing Record 43 of Set 8 | cascais
# Processing Record 44 of Set 8 | pilar
# Processing Record 45 of Set 8 | tukrah
# Processing Record 46 of Set 8 | chicama
# Processing Record 47 of Set 8 | fortuna
# Processing Record 48 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 8 | vysokogornyy
# Processing Record 50 of Set 8 | san juan de los morros
# Processing Record 1 of Set 9 | zhangye
# Processing Record 2 of Set 9 | brandfort
# Processing Record 3 of Set 9 | muros
# Processing Record 4 of Set 9 | bedong
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | margate
# Processing Record 7 of Set 9 | banjar
# Processing Record 8 of Set 9 | faya
# Processing Record 9 of Set 9 | berlevag
# Processing Record 10 of Set 9 | los llanos de aridane
# Processing Record 11 of Set 9 | atambua
# Processing Record 12 of Set 9 | mareeba
# Processing Record 13 of Set 9 | lagoa
# Processing Record 14 of Set 9 | flin flon
# Processing Record 15 of Set 9 | pitsunda
# Processing Record 16 of Set 9 | makakilo city
# Processing Record 17 of Set 9 | laguna
# Processing Record 18 of Set 9 | salamiyah
# Processing Record 19 of Set 9 | quarai
# Processing Record 20 of Set 9 | dores do indaia
# Processing Record 21 of Set 9 | saint george
# Processing Record 22 of Set 9 | uttarkashi
# Processing Record 23 of Set 9 | la palma
# Processing Record 24 of Set 9 | college
# Processing Record 25 of Set 9 | coihaique
# Processing Record 26 of Set 9 | san policarpo
# Processing Record 27 of Set 9 | umm kaddadah
# Processing Record 28 of Set 9 | ilulissat
# Processing Record 29 of Set 9 | saint-georges
# Processing Record 30 of Set 9 | babushkin
# Processing Record 31 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 9 | ganzhou
# Processing Record 33 of Set 9 | khrebtovaya
# Processing Record 34 of Set 9 | jiwani
# Processing Record 35 of Set 9 | wilmington
# Processing Record 36 of Set 9 | arlit
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | luganville
# Processing Record 39 of Set 9 | havelock
# Processing Record 40 of Set 9 | meadow lake
# Processing Record 41 of Set 9 | dom pedrito
# Processing Record 42 of Set 9 | tolbazy
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | lomovka
# Processing Record 45 of Set 9 | vytegra
# Processing Record 46 of Set 9 | buchanan
# Processing Record 47 of Set 9 | monrovia
# Processing Record 48 of Set 9 | caranavi
# Processing Record 49 of Set 9 | walvis bay
# Processing Record 50 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 10 | nome
# Processing Record 3 of Set 10 | sabak
# Processing Record 4 of Set 10 | ransang
# Processing Record 5 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 6 of Set 10 | pudozh
# Processing Record 7 of Set 10 | isangel
# Processing Record 8 of Set 10 | dukat
# Processing Record 9 of Set 10 | hirara
# Processing Record 10 of Set 10 | lufilufi
# Processing Record 11 of Set 10 | haimen
# Processing Record 12 of Set 10 | vostok
# Processing Record 13 of Set 10 | san quintin
# Processing Record 14 of Set 10 | tilichiki
# Processing Record 15 of Set 10 | jacqueville
# Processing Record 16 of Set 10 | zeya
# Processing Record 17 of Set 10 | abnub
# Processing Record 18 of Set 10 | komsomolskiy
# Processing Record 19 of Set 10 | marsh harbour
# Processing Record 20 of Set 10 | port hedland
# Processing Record 21 of Set 10 | dandong
# Processing Record 22 of Set 10 | tezu
# Processing Record 23 of Set 10 | harboore
# Processing Record 24 of Set 10 | adjumani
# Processing Record 25 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 10 | namatanai
# Processing Record 27 of Set 10 | poum
# Processing Record 28 of Set 10 | manzil salim
# Processing Record 29 of Set 10 | talakan
# Processing Record 30 of Set 10 | bontang
# Processing Record 31 of Set 10 | harrisonburg
# Processing Record 32 of Set 10 | kroya
# Processing Record 33 of Set 10 | sayat
# Processing Record 34 of Set 10 | lively
# Processing Record 35 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 10 | udachnyy
# Processing Record 37 of Set 10 | san carlos del zulia
# Processing Record 38 of Set 10 | lakes entrance
# Processing Record 39 of Set 10 | northam
# Processing Record 40 of Set 10 | qingyuan
# Processing Record 41 of Set 10 | batemans bay
# Processing Record 42 of Set 10 | ixtapa
# Processing Record 43 of Set 10 | karaton
# Processing Record 44 of Set 10 | calvia
# Processing Record 45 of Set 10 | kindu
# Processing Record 46 of Set 10 | ekhabi
# Processing Record 47 of Set 10 | kabanjahe
# Processing Record 48 of Set 10 | trairi
# Processing Record 49 of Set 10 | qui nhon
# Processing Record 50 of Set 10 | surgut
# Processing Record 1 of Set 11 | leeton
# Processing Record 2 of Set 11 | elhovo
# Processing Record 3 of Set 11 | grand-lahou
# Processing Record 4 of Set 11 | acajutla
# Processing Record 5 of Set 11 | sisimiut
# Processing Record 6 of Set 11 | southbridge
# Processing Record 7 of Set 11 | ishigaki
# Processing Record 8 of Set 11 | altamont
# Processing Record 9 of Set 11 | touros
# Processing Record 10 of Set 11 | baikunthpur
# Processing Record 11 of Set 11 | dubuque
# Processing Record 12 of Set 11 | srednekolymsk
# Processing Record 13 of Set 11 | moyale
# Processing Record 14 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 11 | saint-michel-des-saints
# Processing Record 16 of Set 11 | innisfail
# Processing Record 17 of Set 11 | sungairaya
# Processing Record 18 of Set 11 | egvekinot
# Processing Record 19 of Set 11 | horve
# Processing Record 20 of Set 11 | goure
# Processing Record 21 of Set 11 | am timan
# Processing Record 22 of Set 11 | nova olimpia
# Processing Record 23 of Set 11 | malvern
# Processing Record 24 of Set 11 | inverell
# Processing Record 25 of Set 11 | qaqortoq
# Processing Record 26 of Set 11 | mount pleasant
# Processing Record 27 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 11 | chuy
# Processing Record 29 of Set 11 | belaya gora
# Processing Record 30 of Set 11 | shu
# Processing Record 31 of Set 11 | bemidji
# Processing Record 32 of Set 11 | kologriv
# Processing Record 33 of Set 11 | aswan
# Processing Record 34 of Set 11 | olinda
# Processing Record 35 of Set 11 | sur
# Processing Record 36 of Set 11 | clyde
# Processing Record 37 of Set 11 | lumphat
# Processing Record 38 of Set 11 | torrington
# Processing Record 39 of Set 11 | porbandar
# Processing Record 40 of Set 11 | vestmanna
# Processing Record 41 of Set 11 | murakami
# Processing Record 42 of Set 11 | alofi
# Processing Record 43 of Set 11 | puerto madryn
# Processing Record 44 of Set 11 | mingaora
# Processing Record 45 of Set 11 | talnakh
# Processing Record 46 of Set 11 | kampot
# Processing Record 47 of Set 11 | camacha
# Processing Record 48 of Set 11 | goma
# Processing Record 49 of Set 11 | san cristobal
# Processing Record 50 of Set 11 | puro
# Processing Record 1 of Set 12 | cabedelo
# Processing Record 2 of Set 12 | maarianhamina
# Processing Record 3 of Set 12 | tautira
# Processing Record 4 of Set 12 | mae sai
# Processing Record 5 of Set 12 | kieta
# Processing Record 6 of Set 12 | loralai
# Processing Record 7 of Set 12 | atasu
# Processing Record 8 of Set 12 | copiapo
# Processing Record 9 of Set 12 | enterprise
# Processing Record 10 of Set 12 | yarada
# Processing Record 11 of Set 12 | kobojango
# City not found. Skipping...
# Processing Record 12 of Set 12 | key west
# Processing Record 13 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | flinders
# Processing Record 15 of Set 12 | launceston
# Processing Record 16 of Set 12 | dunedin
# Processing Record 17 of Set 12 | sterling
# Processing Record 18 of Set 12 | porto novo
# Processing Record 19 of Set 12 | hauterive
# Processing Record 20 of Set 12 | douglas
# Processing Record 21 of Set 12 | basco
# Processing Record 22 of Set 12 | bandar-e lengeh
# Processing Record 23 of Set 12 | grindavik
# Processing Record 24 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 25 of Set 12 | limache
# Processing Record 26 of Set 12 | ribeira brava
# Processing Record 27 of Set 12 | ostrovnoy
# Processing Record 28 of Set 12 | nouakchott
# Processing Record 29 of Set 12 | rundu
# Processing Record 30 of Set 12 | diego de almagro
# Processing Record 31 of Set 12 | hammerfest
# Processing Record 32 of Set 12 | sibut
# Processing Record 33 of Set 12 | lahij
# Processing Record 34 of Set 12 | sebina
# Processing Record 35 of Set 12 | oranjemund
# Processing Record 36 of Set 12 | lev tolstoy
# Processing Record 37 of Set 12 | aksarka
# Processing Record 38 of Set 12 | jawhar
# Processing Record 39 of Set 12 | fairbanks
# Processing Record 40 of Set 12 | kiunga
# Processing Record 41 of Set 12 | hualmay
# Processing Record 42 of Set 12 | usogorsk
# Processing Record 43 of Set 12 | nizhniy tagil
# Processing Record 44 of Set 12 | mahibadhoo
# Processing Record 45 of Set 12 | akdepe
# Processing Record 46 of Set 12 | witrivier
# City not found. Skipping...
# Processing Record 47 of Set 12 | havre-saint-pierre
# Processing Record 48 of Set 12 | ailigandi
# Processing Record 49 of Set 12 | marzuq
# Processing Record 50 of Set 12 | arman
# Processing Record 1 of Set 13 | kenai
# Processing Record 2 of Set 13 | newala
# Processing Record 3 of Set 13 | vallenar
# Processing Record 4 of Set 13 | abramovka
# Processing Record 5 of Set 13 | aykhal
# Processing Record 6 of Set 13 | odienne
# Processing Record 7 of Set 13 | ternate
# Processing Record 8 of Set 13 | tazmalt
# Processing Record 9 of Set 13 | capaccio
# Processing Record 10 of Set 13 | odessa
# Processing Record 11 of Set 13 | ahipara
# Processing Record 12 of Set 13 | santa fe
# Processing Record 13 of Set 13 | kemin
# Processing Record 14 of Set 13 | kirovskiy
# Processing Record 15 of Set 13 | les cayes
# Processing Record 16 of Set 13 | luanda
# Processing Record 17 of Set 13 | zheleznodorozhnyy
# Processing Record 18 of Set 13 | tuatapere
# Processing Record 19 of Set 13 | maputo
# Processing Record 20 of Set 13 | ucluelet
# Processing Record 21 of Set 13 | erzincan
# Processing Record 22 of Set 13 | tharad
# Processing Record 23 of Set 13 | manta
# Processing Record 24 of Set 13 | yerbogachen
# Processing Record 25 of Set 13 | szydlowiec
# Processing Record 26 of Set 13 | naze
# Processing Record 27 of Set 13 | edendale
# Processing Record 28 of Set 13 | novo oriente
# Processing Record 29 of Set 13 | adre
# Processing Record 30 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 13 | buritis
# Processing Record 32 of Set 13 | nakamura
# Processing Record 33 of Set 13 | ivankiv
# Processing Record 34 of Set 13 | codrington
# Processing Record 35 of Set 13 | maneadero
# Processing Record 36 of Set 13 | bilibino
# Processing Record 37 of Set 13 | mumbwa
# Processing Record 38 of Set 13 | mayumba
# Processing Record 39 of Set 13 | paamiut
# Processing Record 40 of Set 13 | kisangani
# Processing Record 41 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 13 | quesnel
# Processing Record 43 of Set 13 | birjand
# Processing Record 44 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 45 of Set 13 | clarence town
# Processing Record 46 of Set 13 | la union
# Processing Record 47 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 13 | nagato
# Processing Record 49 of Set 13 | bartica
# Processing Record 50 of Set 13 | nicoya
# Processing Record 1 of Set 14 | sioux city
# Processing Record 2 of Set 14 | bourail
# Processing Record 3 of Set 14 | morgan city
# Processing Record 4 of Set 14 | natal
# Processing Record 5 of Set 14 | kharp
# Processing Record 6 of Set 14 | yangjiang
# Processing Record 7 of Set 14 | amapa
# Processing Record 8 of Set 14 | george town
# Processing Record 9 of Set 14 | digboi
# Processing Record 10 of Set 14 | alice springs
# Processing Record 11 of Set 14 | conil
# Processing Record 12 of Set 14 | naryan-mar
# Processing Record 13 of Set 14 | liverpool
# Processing Record 14 of Set 14 | bata
# Processing Record 15 of Set 14 | chatellerault
# Processing Record 16 of Set 14 | san onofre
# Processing Record 17 of Set 14 | taltal
# Processing Record 18 of Set 14 | salalah
# Processing Record 19 of Set 14 | kedrovyy
# Processing Record 20 of Set 14 | andrelandia
# Processing Record 21 of Set 14 | otta
# Processing Record 22 of Set 14 | port-gentil
# Processing Record 23 of Set 14 | reconquista
# Processing Record 24 of Set 14 | kaseda
# Processing Record 25 of Set 14 | grants pass
# Processing Record 26 of Set 14 | nara
# Processing Record 27 of Set 14 | matay
# Processing Record 28 of Set 14 | aykino
# Processing Record 29 of Set 14 | lensk
# Processing Record 30 of Set 14 | palanpur
# Processing Record 31 of Set 14 | lahad datu
# Processing Record 32 of Set 14 | bardiyah
# Processing Record 33 of Set 14 | gijon
# Processing Record 34 of Set 14 | wundanyi
# Processing Record 35 of Set 14 | chabahar
# Processing Record 36 of Set 14 | puerto cabello
# Processing Record 37 of Set 14 | yibin
# Processing Record 38 of Set 14 | portland
# Processing Record 39 of Set 14 | traverse city
# Processing Record 40 of Set 14 | varhaug
# Processing Record 41 of Set 14 | bosaso
# Processing Record 42 of Set 14 | acapulco
# Processing Record 43 of Set 14 | koster
# Processing Record 44 of Set 14 | keita
# Processing Record 45 of Set 14 | sedalia
# Processing Record 46 of Set 14 | xining
# Processing Record 47 of Set 14 | poitiers
# Processing Record 48 of Set 14 | zhanakorgan
# Processing Record 49 of Set 14 | bereda
# Processing Record 50 of Set 14 | pangnirtung
# Processing Record 1 of Set 15 | sarandi
# Processing Record 2 of Set 15 | lazarev
# Processing Record 3 of Set 15 | port hardy
# Processing Record 4 of Set 15 | vestmannaeyjar
# Processing Record 5 of Set 15 | tual
# Processing Record 6 of Set 15 | yurga
# Processing Record 7 of Set 15 | umm lajj
# Processing Record 8 of Set 15 | nenjiang
# Processing Record 9 of Set 15 | bandarbeyla
# Processing Record 10 of Set 15 | agadez
# Processing Record 11 of Set 15 | marratxi
# Processing Record 12 of Set 15 | wenzhou
# Processing Record 13 of Set 15 | maniitsoq
# Processing Record 14 of Set 15 | tadine
# Processing Record 15 of Set 15 | taiyuan
# Processing Record 16 of Set 15 | samatau
# City not found. Skipping...
# Processing Record 17 of Set 15 | morant bay
# Processing Record 18 of Set 15 | sibolga
# Processing Record 19 of Set 15 | namtsy
# Processing Record 20 of Set 15 | narrabri
# Processing Record 21 of Set 15 | qiongshan
# Processing Record 22 of Set 15 | havoysund
# Processing Record 23 of Set 15 | jurm
# Processing Record 24 of Set 15 | belmonte
# Processing Record 25 of Set 15 | bose
# Processing Record 26 of Set 15 | dekar
# Processing Record 27 of Set 15 | malabo
# Processing Record 28 of Set 15 | shwebo
# Processing Record 29 of Set 15 | yeniseysk
# Processing Record 30 of Set 15 | jacmel
# Processing Record 31 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 32 of Set 15 | dhidhdhoo
# Processing Record 33 of Set 15 | matadi
# Processing Record 34 of Set 15 | paranhos
# Processing Record 35 of Set 15 | jutai
# Processing Record 36 of Set 15 | angul
# Processing Record 37 of Set 15 | sao tome
# Processing Record 38 of Set 15 | roma
# Processing Record 39 of Set 15 | biak
# Processing Record 40 of Set 15 | zafra
# Processing Record 41 of Set 15 | esso
# Processing Record 42 of Set 15 | gondar
# Processing Record 43 of Set 15 | soyo
# Processing Record 44 of Set 15 | utete
# Processing Record 45 of Set 15 | farah
# Processing Record 46 of Set 15 | narsaq
# Processing Record 47 of Set 15 | umea
# Processing Record 48 of Set 15 | athni
# Processing Record 49 of Set 15 | sao jose da coroa grande
# Processing Record 50 of Set 15 | alappuzha
# Processing Record 1 of Set 16 | tapaua
# City not found. Skipping...
# Processing Record 2 of Set 16 | teo
# Processing Record 3 of Set 16 | sabzevar
# Processing Record 4 of Set 16 | rancho palos verdes
# Processing Record 5 of Set 16 | ambilobe
# Processing Record 6 of Set 16 | belize
# Processing Record 7 of Set 16 | okuchi
# Processing Record 8 of Set 16 | lake elsinore
# Processing Record 9 of Set 16 | virginia beach
# Processing Record 10 of Set 16 | chongoyape
# Processing Record 11 of Set 16 | antofagasta
# Processing Record 12 of Set 16 | zlitan
# Processing Record 13 of Set 16 | nizhnyaya tavda
# Processing Record 14 of Set 16 | tanete
# Processing Record 15 of Set 16 | prince rupert
# Processing Record 16 of Set 16 | nichinan
# Processing Record 17 of Set 16 | sao joao da barra
# Processing Record 18 of Set 16 | farafangana
# Processing Record 19 of Set 16 | kamenka
# Processing Record 20 of Set 16 | imbituba
# Processing Record 21 of Set 16 | konya
# Processing Record 22 of Set 16 | gazojak
# Processing Record 23 of Set 16 | barra patuca
# Processing Record 24 of Set 16 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 16 | mariental
# Processing Record 26 of Set 16 | palmer
# Processing Record 27 of Set 16 | atherton
# Processing Record 28 of Set 16 | zabol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Current Description': 'clear sky',
#   'Max Temp': 60.85,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 12.57,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:39:59'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 77.9,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 14.5,
#   'Country': 'GH',
#   'Date': '2022-07-28 16:39:59'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Current Description': 'broken clouds',
#   'Max Temp': 72.61,
#   'Humidity': 76,
#   'Cloudiness': 79,
#   'Wind Speed': 5.97,
#   'Country': 'GA',
#   'Date': '2022-07-28 16:39:59'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Current Description': 'clear sky',
#   'Max Temp': 39.96,
#   'Humidity': 70,
#   'Cloudiness': 9,
#   'Wind Speed': 1.19,
#   'Country': 'GL',
#   'Date': '2022-07-28 16:40:00'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 88.57,
#   'Humidity': 61,
#   'Cloudiness': 26,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-07-28 16:39:35'},
#  {'City': 'Saint Pete Beach',
#   'Lat': 27.7253,
#   'Lng': -82.7412,
#   'Current Description': 'clear sky',
#   'Max Temp': 93.24,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2022-07-28 16:40:00'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Current Description': 'light rain',
#   'Max Temp': 78.53,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-07-28 16:40:01'},
#  {'City': 'Belgrade',
#   'Lat': 44.804,
#   'Lng': 20.4651,
#   'Current Description': 'clear sky',
#   'Max Temp': 83.86,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'RS',
#   'Date': '2022-07-28 16:35:03'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Current Description': 'broken clouds',
#   'Max Temp': 73.56,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'TO',
#   'Date': '2022-07-28 16:40:01'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 92.05,
#   'Humidity': 26,
#   'Cloudiness': 34,
#   'Wind Speed': 8.66,
#   'Country': 'SA',
#   'Date': '2022-07-28 16:40:02'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Current Description': 'clear sky',
#   'Max Temp': 73.35,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 20.65,
#   'Country': 'PF',
#   'Date': '2022-07-28 16:40:02'},
#  {'City': 'Oranjestad',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Current Description': 'few clouds',
#   'Max Temp': 87.75,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'AW',
#   'Date': '2022-07-28 16:38:53'},
#  {'City': 'Moerai',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Current Description': 'broken clouds',
#   'Max Temp': 73,
#   'Humidity': 77,
#   'Cloudiness': 54,
#   'Wind Speed': 23.42,
#   'Country': 'PF',
#   'Date': '2022-07-28 16:40:03'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Current Description': 'clear sky',
#   'Max Temp': 93.74,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 12.46,
#   'Country': 'SY',
#   'Date': '2022-07-28 16:40:04'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Current Description': 'clear sky',
#   'Max Temp': 77.29,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2022-07-28 16:40:04'},
#  {'City': 'Miyako',
#   'Lat': 39.6367,
#   'Lng': 141.9525,
#   'Current Description': 'clear sky',
#   'Max Temp': 70.93,
#   'Humidity': 94,
#   'Cloudiness': 5,
#   'Wind Speed': 2.33,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:40:05'},
#  {'City': 'Porto Walter',
#   'Lat': -8.2686,
#   'Lng': -72.7439,
#   'Current Description': 'broken clouds',
#   'Max Temp': 92.52,
#   'Humidity': 43,
#   'Cloudiness': 69,
#   'Wind Speed': 1.34,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:40:06'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 71.19,
#   'Humidity': 82,
#   'Cloudiness': 45,
#   'Wind Speed': 7.4,
#   'Country': 'RE',
#   'Date': '2022-07-28 16:40:06'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 88.36,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2022-07-28 16:38:16'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Current Description': 'broken clouds',
#   'Max Temp': 46.06,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'AR',
#   'Date': '2022-07-28 16:40:07'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 71.26,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'MU',
#   'Date': '2022-07-28 16:40:07'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Current Description': 'clear sky',
#   'Max Temp': 65.88,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 4.72,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:40:08'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Current Description': 'light rain',
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:40:08'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 44.37,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 17.63,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:40:09'},
#  {'City': 'Izumo',
#   'Lat': 35.3667,
#   'Lng': 132.7667,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 78.75,
#   'Humidity': 91,
#   'Cloudiness': 31,
#   'Wind Speed': 5.32,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:40:09'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 80.73,
#   'Humidity': 77,
#   'Cloudiness': 86,
#   'Wind Speed': 12.93,
#   'Country': 'GW',
#   'Date': '2022-07-28 16:40:10'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Current Description': 'few clouds',
#   'Max Temp': 72.75,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:35:30'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 80.56,
#   'Humidity': 75,
#   'Cloudiness': 25,
#   'Wind Speed': 12.55,
#   'Country': 'CV',
#   'Date': '2022-07-28 16:40:11'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 52.2,
#   'Humidity': 84,
#   'Cloudiness': 26,
#   'Wind Speed': 3.8,
#   'Country': 'TL',
#   'Date': '2022-07-28 16:40:12'},
#  {'City': 'Usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Current Description': 'few clouds',
#   'Max Temp': 67.39,
#   'Humidity': 52,
#   'Cloudiness': 16,
#   'Wind Speed': 12.53,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:40:12'},
#  {'City': 'Mesetas',
#   'Lat': 3.3846,
#   'Lng': -74.0442,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 70.65,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'CO',
#   'Date': '2022-07-28 16:40:13'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Current Description': 'clear sky',
#   'Max Temp': 53.74,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 13.22,
#   'Country': 'CL',
#   'Date': '2022-07-28 16:39:00'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 54.52,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 16.33,
#   'Country': 'FO',
#   'Date': '2022-07-28 16:40:13'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Current Description': 'light rain',
#   'Max Temp': 62.91,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:40:14'},
#  {'City': 'Abiramam',
#   'Lat': 9.4667,
#   'Lng': 78.45,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 83.08,
#   'Humidity': 72,
#   'Cloudiness': 98,
#   'Wind Speed': 9.44,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:40:16'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Current Description': 'moderate rain',
#   'Max Temp': 57.09,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2022-07-28 16:40:17'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Current Description': 'light rain',
#   'Max Temp': 62.02,
#   'Humidity': 86,
#   'Cloudiness': 42,
#   'Wind Speed': 19.6,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:40:17'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 47.48,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'NZ',
#   'Date': '2022-07-28 16:39:14'},
#  {'City': 'Jiazi',
#   'Lat': 22.8779,
#   'Lng': 116.067,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 83.64,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:40:18'},
#  {'City': 'Dakar',
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 85.08,
#   'Humidity': 71,
#   'Cloudiness': 96,
#   'Wind Speed': 16.89,
#   'Country': 'SN',
#   'Date': '2022-07-28 16:40:18'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Current Description': 'clear sky',
#   'Max Temp': 74.25,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': '2022-07-28 16:40:19'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Current Description': 'broken clouds',
#   'Max Temp': 77.09,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'OM',
#   'Date': '2022-07-28 16:40:19'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 44.62,
#   'Humidity': 58,
#   'Cloudiness': 88,
#   'Wind Speed': 9.35,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:35:30'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 104.45,
#   'Humidity': 11,
#   'Cloudiness': 100,
#   'Wind Speed': 9.6,
#   'Country': 'SA',
#   'Date': '2022-07-28 16:40:20'},
#  {'City': 'Hirtshals',
#   'Lat': 57.5881,
#   'Lng': 9.9592,
#   'Current Description': 'few clouds',
#   'Max Temp': 62.56,
#   'Humidity': 67,
#   'Cloudiness': 19,
#   'Wind Speed': 4.79,
#   'Country': 'DK',
#   'Date': '2022-07-28 16:40:21'},
#  {'City': 'Abnub',
#   'Lat': 27.2696,
#   'Lng': 31.1511,
#   'Current Description': 'clear sky',
#   'Max Temp': 100.62,
#   'Humidity': 12,
#   'Cloudiness': 7,
#   'Wind Speed': 8.55,
#   'Country': 'EG',
#   'Date': '2022-07-28 16:40:21'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Current Description': 'clear sky',
#   'Max Temp': 54.21,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:41:22'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Current Description': 'clear sky',
#   'Max Temp': 87.76,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:39:35'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Current Description': 'clear sky',
#   'Max Temp': 89.4,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 10.45,
#   'Country': 'IL',
#   'Date': '2022-07-28 16:41:22'},
#  {'City': 'Campbell River',
#   'Lat': 50.0163,
#   'Lng': -125.2446,
#   'Current Description': 'clear sky',
#   'Max Temp': 77.38,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:37:33'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 47.8,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.89,
#   'Country': 'NZ',
#   'Date': '2022-07-28 16:41:23'},
#  {'City': 'Cururupu',
#   'Lat': -1.8283,
#   'Lng': -44.8683,
#   'Current Description': 'light rain',
#   'Max Temp': 84.02,
#   'Humidity': 61,
#   'Cloudiness': 35,
#   'Wind Speed': 5.37,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:41:23'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Current Description': 'clear sky',
#   'Max Temp': 56.32,
#   'Humidity': 62,
#   'Cloudiness': 7,
#   'Wind Speed': 5.17,
#   'Country': 'IS',
#   'Date': '2022-07-28 16:41:23'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 73.74,
#   'Humidity': 71,
#   'Cloudiness': 98,
#   'Wind Speed': 12.21,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:41:24'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 82.65,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 16.69,
#   'Country': 'PG',
#   'Date': '2022-07-28 16:38:53'},
#  {'City': 'Andapa',
#   'Lat': -14.65,
#   'Lng': 49.65,
#   'Current Description': 'broken clouds',
#   'Max Temp': 61.09,
#   'Humidity': 97,
#   'Cloudiness': 74,
#   'Wind Speed': 2.08,
#   'Country': 'MG',
#   'Date': '2022-07-28 16:41:24'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Current Description': 'few clouds',
#   'Max Temp': 82.33,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 7,
#   'Country': 'MY',
#   'Date': '2022-07-28 16:40:35'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Current Description': 'broken clouds',
#   'Max Temp': 74.73,
#   'Humidity': 42,
#   'Cloudiness': 60,
#   'Wind Speed': 11.18,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:36:34'},
#  {'City': 'Salinas',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Current Description': 'haze',
#   'Max Temp': 65.21,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2022-07-28 16:39:31'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 68.47,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:41:25'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 33.15,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.2,
#   'Country': 'US',
#   'Date': '2022-07-28 16:41:25'},
#  {'City': 'Katobu',
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Current Description': 'broken clouds',
#   'Max Temp': 72.97,
#   'Humidity': 85,
#   'Cloudiness': 54,
#   'Wind Speed': 4.72,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:41:26'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Current Description': 'clear sky',
#   'Max Temp': 85.42,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2022-07-28 16:41:01'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 51.66,
#   'Humidity': 93,
#   'Cloudiness': 45,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:41:26'},
#  {'City': 'Thiruvananthapuram',
#   'Lat': 8.4833,
#   'Lng': 76.9167,
#   'Current Description': 'light intensity drizzle',
#   'Max Temp': 78.78,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:39:30'},
#  {'City': 'Pozo Colorado',
#   'Lat': -23.4923,
#   'Lng': -58.7972,
#   'Current Description': 'few clouds',
#   'Max Temp': 96.35,
#   'Humidity': 18,
#   'Cloudiness': 18,
#   'Wind Speed': 12.86,
#   'Country': 'PY',
#   'Date': '2022-07-28 16:41:27'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Current Description': 'broken clouds',
#   'Max Temp': 90.32,
#   'Humidity': 19,
#   'Cloudiness': 63,
#   'Wind Speed': 16.11,
#   'Country': 'UZ',
#   'Date': '2022-07-28 16:41:27'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 76.96,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 10,
#   'Country': 'EC',
#   'Date': '2022-07-28 16:41:28'},
#  {'City': 'Yagodnoye',
#   'Lat': 62.55,
#   'Lng': 149.6667,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 52.38,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:41:28'},
#  {'City': 'Seoul',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 83.8,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'KR',
#   'Date': '2022-07-28 16:37:43'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Current Description': 'broken clouds',
#   'Max Temp': 48.45,
#   'Humidity': 65,
#   'Cloudiness': 76,
#   'Wind Speed': 1.88,
#   'Country': 'GL',
#   'Date': '2022-07-28 16:41:28'},
#  {'City': 'Burgeo',
#   'Lat': 47.6167,
#   'Lng': -57.6152,
#   'Current Description': 'broken clouds',
#   'Max Temp': 67.39,
#   'Humidity': 71,
#   'Cloudiness': 61,
#   'Wind Speed': 5.39,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:41:29'},
#  {'City': 'Fortuna Foothills',
#   'Lat': 32.6578,
#   'Lng': -114.4119,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 91.49,
#   'Humidity': 40,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Date': '2022-07-28 16:41:29'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 52.57,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.03,
#   'Country': 'UY',
#   'Date': '2022-07-28 16:41:30'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 80.11,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'LK',
#   'Date': '2022-07-28 16:41:30'},
#  {'City': 'Chopovychi',
#   'Lat': 50.8332,
#   'Lng': 28.9533,
#   'Current Description': 'broken clouds',
#   'Max Temp': 70.88,
#   'Humidity': 54,
#   'Cloudiness': 62,
#   'Wind Speed': 5.79,
#   'Country': 'UA',
#   'Date': '2022-07-28 16:41:30'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Current Description': 'light rain',
#   'Max Temp': 39.43,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:41:06'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Current Description': 'light rain',
#   'Max Temp': 41.11,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 31.07,
#   'Country': 'CL',
#   'Date': '2022-07-28 16:39:38'},
#  {'City': 'Umba',
#   'Lat': 66.6871,
#   'Lng': 34.3429,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 55.31,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 11.48,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:41:31'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 75.25,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CK',
#   'Date': '2022-07-28 16:37:01'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 88.32,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Country': 'HK',
#   'Date': '2022-07-28 16:40:18'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 86.23,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'MX',
#   'Date': '2022-07-28 16:41:32'},
#  {'City': 'Rorvik',
#   'Lat': 64.8621,
#   'Lng': 11.2373,
#   'Current Description': 'broken clouds',
#   'Max Temp': 57.18,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:41:32'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.72,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 18.19,
#   'Country': 'MV',
#   'Date': '2022-07-28 16:41:33'},
#  {'City': 'Andros Town',
#   'Lat': 24.7,
#   'Lng': -77.7667,
#   'Current Description': 'clear sky',
#   'Max Temp': 87.76,
#   'Humidity': 68,
#   'Cloudiness': 9,
#   'Wind Speed': 16.24,
#   'Country': 'BS',
#   'Date': '2022-07-28 16:41:33'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 69.87,
#   'Humidity': 61,
#   'Cloudiness': 93,
#   'Wind Speed': 4.72,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:38:25'},
#  {'City': 'Victoria Point',
#   'Lat': -27.5833,
#   'Lng': 153.3,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 52.95,
#   'Humidity': 92,
#   'Cloudiness': 37,
#   'Wind Speed': 5.95,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:41:34'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Current Description': 'moderate rain',
#   'Max Temp': 76.87,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 4.68,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:41:34'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 63.12,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:41:34'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Current Description': 'few clouds',
#   'Max Temp': 43.05,
#   'Humidity': 70,
#   'Cloudiness': 19,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:37:06'},
#  {'City': 'Puro',
#   'Lat': 12.4841,
#   'Lng': 123.3827,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.43,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.64,
#   'Country': 'PH',
#   'Date': '2022-07-28 16:41:35'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 60.94,
#   'Humidity': 57,
#   'Cloudiness': 48,
#   'Wind Speed': 4.85,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:41:35'},
#  {'City': 'Aljezur',
#   'Lat': 37.3191,
#   'Lng': -8.8033,
#   'Current Description': 'clear sky',
#   'Max Temp': 74.59,
#   'Humidity': 71,
#   'Cloudiness': 4,
#   'Wind Speed': 15.3,
#   'Country': 'PT',
#   'Date': '2022-07-28 16:41:36'},
#  {'City': 'Praya',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Current Description': 'few clouds',
#   'Max Temp': 88.34,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CV',
#   'Date': '2022-07-28 16:42:36'},
#  {'City': 'Alberton',
#   'Lat': 46.8168,
#   'Lng': -64.0654,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 75.33,
#   'Humidity': 69,
#   'Cloudiness': 29,
#   'Wind Speed': 4.68,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:42:21'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Current Description': 'broken clouds',
#   'Max Temp': 65.95,
#   'Humidity': 71,
#   'Cloudiness': 57,
#   'Wind Speed': 8.9,
#   'Country': 'PE',
#   'Date': '2022-07-28 16:42:36'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Current Description': 'broken clouds',
#   'Max Temp': 53.58,
#   'Humidity': 82,
#   'Cloudiness': 64,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:42:37'},
#  {'City': 'Vestmanna',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 52.72,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'FO',
#   'Date': '2022-07-28 16:42:37'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 69.94,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:42:38'},
#  {'City': 'Abatskoye',
#   'Lat': 56.2875,
#   'Lng': 70.4555,
#   'Current Description': 'light rain',
#   'Max Temp': 62.29,
#   'Humidity': 95,
#   'Cloudiness': 93,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:38'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Current Description': 'light rain',
#   'Max Temp': 75.52,
#   'Humidity': 91,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-07-28 16:42:38'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Current Description': 'broken clouds',
#   'Max Temp': 74.32,
#   'Humidity': 91,
#   'Cloudiness': 67,
#   'Wind Speed': 3.11,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:42:39'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.7,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 15.3,
#   'Country': 'KI',
#   'Date': '2022-07-28 16:42:39'},
#  {'City': 'Suleya',
#   'Lat': 55.1352,
#   'Lng': 58.8792,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 57.85,
#   'Humidity': 79,
#   'Cloudiness': 85,
#   'Wind Speed': 3.78,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:40'},
#  {'City': 'Khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 64.8,
#   'Humidity': 72,
#   'Cloudiness': 47,
#   'Wind Speed': 2.89,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:40'},
#  {'City': 'Wapi Pathum',
#   'Lat': 15.8452,
#   'Lng': 103.3768,
#   'Current Description': 'broken clouds',
#   'Max Temp': 83.32,
#   'Humidity': 69,
#   'Cloudiness': 64,
#   'Wind Speed': 6.49,
#   'Country': 'TH',
#   'Date': '2022-07-28 16:42:40'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Current Description': 'clear sky',
#   'Max Temp': 55.8,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 4.14,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:42:41'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Current Description': 'broken clouds',
#   'Max Temp': 86.47,
#   'Humidity': 61,
#   'Cloudiness': 58,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2022-07-28 16:42:41'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 52.39,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:41'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Current Description': 'clear sky',
#   'Max Temp': 76.84,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2022-07-28 16:38:24'},
#  {'City': 'Mabaruma',
#   'Lat': 8.2,
#   'Lng': -59.7833,
#   'Current Description': 'few clouds',
#   'Max Temp': 90.21,
#   'Humidity': 52,
#   'Cloudiness': 22,
#   'Wind Speed': 5.64,
#   'Country': 'GY',
#   'Date': '2022-07-28 16:42:42'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Current Description': 'few clouds',
#   'Max Temp': 68.16,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:42:42'},
#  {'City': 'Wuda',
#   'Lat': 39.4994,
#   'Lng': 106.7117,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 81.28,
#   'Humidity': 23,
#   'Cloudiness': 35,
#   'Wind Speed': 11.23,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:42:43'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Current Description': 'broken clouds',
#   'Max Temp': 84.22,
#   'Humidity': 79,
#   'Cloudiness': 65,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:42:43'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Current Description': 'few clouds',
#   'Max Temp': 48.22,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'GL',
#   'Date': '2022-07-28 16:42:44'},
#  {'City': 'Shujaabad',
#   'Lat': 29.8797,
#   'Lng': 71.2931,
#   'Current Description': 'light rain',
#   'Max Temp': 84.25,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 11.72,
#   'Country': 'PK',
#   'Date': '2022-07-28 16:42:44'},
#  {'City': 'Qeshm',
#   'Lat': 26.9581,
#   'Lng': 56.2719,
#   'Current Description': 'broken clouds',
#   'Max Temp': 87.69,
#   'Humidity': 75,
#   'Cloudiness': 81,
#   'Wind Speed': 20.89,
#   'Country': 'IR',
#   'Date': '2022-07-28 16:42:44'},
#  {'City': 'Kardymovo',
#   'Lat': 54.8902,
#   'Lng': 32.4311,
#   'Current Description': 'broken clouds',
#   'Max Temp': 62.78,
#   'Humidity': 72,
#   'Cloudiness': 77,
#   'Wind Speed': 7.61,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:45'},
#  {'City': 'Borovoy',
#   'Lat': 55.4333,
#   'Lng': 86.0833,
#   'Current Description': 'clear sky',
#   'Max Temp': 67.28,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:45'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Current Description': 'broken clouds',
#   'Max Temp': 55.62,
#   'Humidity': 74,
#   'Cloudiness': 70,
#   'Wind Speed': 10.89,
#   'Country': 'NZ',
#   'Date': '2022-07-28 16:42:45'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 76.87,
#   'Humidity': 87,
#   'Cloudiness': 87,
#   'Wind Speed': 3.02,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:42:46'},
#  {'City': 'Varhaug',
#   'Lat': 58.6147,
#   'Lng': 5.6457,
#   'Current Description': 'clear sky',
#   'Max Temp': 64.69,
#   'Humidity': 72,
#   'Cloudiness': 7,
#   'Wind Speed': 10.74,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:42:46'},
#  {'City': 'Quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Current Description': 'broken clouds',
#   'Max Temp': 69.75,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'MZ',
#   'Date': '2022-07-28 16:42:47'},
#  {'City': 'Zheleznodorozhnyy',
#   'Lat': 55.7503,
#   'Lng': 38.0042,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 72.21,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 10.56,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:47'},
#  {'City': 'Mbalmayo',
#   'Lat': 3.5167,
#   'Lng': 11.5,
#   'Current Description': 'light rain',
#   'Max Temp': 68.92,
#   'Humidity': 97,
#   'Cloudiness': 77,
#   'Wind Speed': 5.1,
#   'Country': 'CM',
#   'Date': '2022-07-28 16:42:47'},
#  {'City': 'Bani',
#   'Lat': 18.2833,
#   'Lng': -70.3333,
#   'Current Description': 'clear sky',
#   'Max Temp': 86.86,
#   'Humidity': 48,
#   'Cloudiness': 7,
#   'Wind Speed': 14.83,
#   'Country': 'DO',
#   'Date': '2022-07-28 16:39:15'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Current Description': 'broken clouds',
#   'Max Temp': 75.6,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'PT',
#   'Date': '2022-07-28 16:42:48'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Current Description': 'light rain',
#   'Max Temp': 65.98,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 7.11,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:42:48'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 39.72,
#   'Humidity': 77,
#   'Cloudiness': 86,
#   'Wind Speed': 2.53,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:49'},
#  {'City': 'Nampula',
#   'Lat': -15.1165,
#   'Lng': 39.2666,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 66.15,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MZ',
#   'Date': '2022-07-28 16:42:49'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 44.76,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Country': 'GL',
#   'Date': '2022-07-28 16:42:49'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Current Description': 'clear sky',
#   'Max Temp': 56.21,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 8.75,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:50'},
#  {'City': 'Tomatlan',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 90.09,
#   'Humidity': 52,
#   'Cloudiness': 87,
#   'Wind Speed': 1.79,
#   'Country': 'MX',
#   'Date': '2022-07-28 16:42:50'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Current Description': 'light intensity drizzle',
#   'Max Temp': 50.09,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'AR',
#   'Date': '2022-07-28 16:39:26'},
#  {'City': 'Dicabisagan',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.47,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'PH',
#   'Date': '2022-07-28 16:42:51'},
#  {'City': 'Trenggalek',
#   'Lat': -8.05,
#   'Lng': 111.7167,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 73.56,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 3.06,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:42:51'},
#  {'City': 'Huilong',
#   'Lat': 31.8111,
#   'Lng': 121.655,
#   'Current Description': 'clear sky',
#   'Max Temp': 83.93,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 11.14,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:42:51'},
#  {'City': 'Esso',
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Current Description': 'light rain',
#   'Max Temp': 51.82,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:42:52'},
#  {'City': 'Batasan',
#   'Lat': 12.7667,
#   'Lng': 120.7833,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.54,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'PH',
#   'Date': '2022-07-28 16:42:52'},
#  {'City': 'Zvenigovo',
#   'Lat': 55.9742,
#   'Lng': 48.0181,
#   'Current Description': 'broken clouds',
#   'Max Temp': 74.35,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 5.91,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:43:53'},
#  {'City': 'Cabcaben',
#   'Lat': 14.454,
#   'Lng': 120.5914,
#   'Current Description': 'heavy intensity rain',
#   'Max Temp': 83.14,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'PH',
#   'Date': '2022-07-28 16:43:53'},
#  {'City': 'Karamadai',
#   'Lat': 11.2406,
#   'Lng': 76.9601,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.18,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 2.15,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:43:53'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Current Description': 'clear sky',
#   'Max Temp': 110.8,
#   'Humidity': 5,
#   'Cloudiness': 0,
#   'Wind Speed': 11.07,
#   'Country': 'MR',
#   'Date': '2022-07-28 16:43:54'},
#  {'City': 'Frontera Comalapa',
#   'Lat': 15.65,
#   'Lng': -92.1333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 82.36,
#   'Humidity': 65,
#   'Cloudiness': 86,
#   'Wind Speed': 2.66,
#   'Country': 'MX',
#   'Date': '2022-07-28 16:43:54'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Current Description': 'few clouds',
#   'Max Temp': 65.17,
#   'Humidity': 82,
#   'Cloudiness': 12,
#   'Wind Speed': 5.01,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:43:54'},
#  {'City': 'Ulkan',
#   'Lat': 57.243,
#   'Lng': 107.3223,
#   'Current Description': 'light rain',
#   'Max Temp': 57.78,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.99,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:43:55'},
#  {'City': 'Aksu',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Current Description': 'broken clouds',
#   'Max Temp': 88.77,
#   'Humidity': 25,
#   'Cloudiness': 66,
#   'Wind Speed': 3.85,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:43:55'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 107.04,
#   'Humidity': 14,
#   'Cloudiness': 95,
#   'Wind Speed': 9.64,
#   'Country': 'ML',
#   'Date': '2022-07-28 16:43:56'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 82.89,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 13.96,
#   'Country': 'MV',
#   'Date': '2022-07-28 16:43:56'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 42.33,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Country': 'NZ',
#   'Date': '2022-07-28 16:43:56'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Current Description': 'broken clouds',
#   'Max Temp': 50.02,
#   'Humidity': 99,
#   'Cloudiness': 81,
#   'Wind Speed': 6.85,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:43:57'},
#  {'City': 'Beitbridge',
#   'Lat': -22.2167,
#   'Lng': 30,
#   'Current Description': 'clear sky',
#   'Max Temp': 68.79,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 10.22,
#   'Country': 'ZW',
#   'Date': '2022-07-28 16:43:57'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Current Description': 'broken clouds',
#   'Max Temp': 52.93,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:43:57'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Current Description': 'few clouds',
#   'Max Temp': 75.4,
#   'Humidity': 61,
#   'Cloudiness': 17,
#   'Wind Speed': 9.8,
#   'Country': 'MX',
#   'Date': '2022-07-28 16:39:46'},
#  {'City': 'Madingou',
#   'Lat': -4.1536,
#   'Lng': 13.55,
#   'Current Description': 'broken clouds',
#   'Max Temp': 83.46,
#   'Humidity': 43,
#   'Cloudiness': 64,
#   'Wind Speed': 5.86,
#   'Country': 'CG',
#   'Date': '2022-07-28 16:43:58'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Current Description': 'clear sky',
#   'Max Temp': 56.71,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2022-07-28 16:43:58'},
#  {'City': 'Ambovombe',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Current Description': 'clear sky',
#   'Max Temp': 67.06,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 14.92,
#   'Country': 'MG',
#   'Date': '2022-07-28 16:43:59'},
#  {'City': 'Trinidad',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Current Description': 'few clouds',
#   'Max Temp': 93.18,
#   'Humidity': 38,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'BO',
#   'Date': '2022-07-28 16:43:59'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 47.21,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 2.35,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:44:00'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 70.79,
#   'Humidity': 77,
#   'Cloudiness': 50,
#   'Wind Speed': 10.56,
#   'Country': 'NC',
#   'Date': '2022-07-28 16:44:00'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 41.47,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 3.42,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:44:00'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Current Description': 'clear sky',
#   'Max Temp': 65.34,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:40:12'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Current Description': 'clear sky',
#   'Max Temp': 91.62,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'MX',
#   'Date': '2022-07-28 16:39:25'},
#  {'City': 'Prince George',
#   'Lat': 53.9166,
#   'Lng': -122.753,
#   'Current Description': 'clear sky',
#   'Max Temp': 77.25,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:39:58'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Current Description': 'clear sky',
#   'Max Temp': 51.57,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:41:15'},
#  {'City': 'Lakselv',
#   'Lat': 70.0513,
#   'Lng': 24.9718,
#   'Current Description': 'broken clouds',
#   'Max Temp': 53.42,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:44:01'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 83.44,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Country': 'SD',
#   'Date': '2022-07-28 16:41:21'},
#  {'City': 'Marion',
#   'Lat': 39.7684,
#   'Lng': -86.1555,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 86.04,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-07-28 16:42:04'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Current Description': 'few clouds',
#   'Max Temp': 85.98,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 5.66,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:44:03'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Current Description': 'light rain',
#   'Max Temp': 79.27,
#   'Humidity': 83,
#   'Cloudiness': 66,
#   'Wind Speed': 8.14,
#   'Country': 'SB',
#   'Date': '2022-07-28 16:44:03'},
#  {'City': 'Aligudarz',
#   'Lat': 33.4006,
#   'Lng': 49.6949,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 73.9,
#   'Humidity': 46,
#   'Cloudiness': 48,
#   'Wind Speed': 4.43,
#   'Country': 'IR',
#   'Date': '2022-07-28 16:44:04'},
#  {'City': 'Santiago De Cao',
#   'Lat': -7.9589,
#   'Lng': -79.2392,
#   'Current Description': 'mist',
#   'Max Temp': 60.93,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'PE',
#   'Date': '2022-07-28 16:44:04'},
#  {'City': 'Longyan',
#   'Lat': 25.1072,
#   'Lng': 117.0225,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 72.03,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:44:05'},
#  {'City': 'Dieppe',
#   'Lat': 49.75,
#   'Lng': 1.1667,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 77.18,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'FR',
#   'Date': '2022-07-28 16:42:28'},
#  {'City': 'Tigzirt',
#   'Lat': 36.8886,
#   'Lng': 4.1198,
#   'Current Description': 'clear sky',
#   'Max Temp': 84.49,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 9.35,
#   'Country': 'DZ',
#   'Date': '2022-07-28 16:44:05'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 53.1,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 3.29,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:41:41'},
#  {'City': 'Trairi',
#   'Lat': -3.2778,
#   'Lng': -39.2689,
#   'Current Description': 'broken clouds',
#   'Max Temp': 85.14,
#   'Humidity': 56,
#   'Cloudiness': 51,
#   'Wind Speed': 15.39,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:44:06'},
#  {'City': 'Monywa',
#   'Lat': 22.1167,
#   'Lng': 95.1333,
#   'Current Description': 'broken clouds',
#   'Max Temp': 90.68,
#   'Humidity': 58,
#   'Cloudiness': 77,
#   'Wind Speed': 5.06,
#   'Country': 'MM',
#   'Date': '2022-07-28 16:44:07'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 74.32,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 3.69,
#   'Country': 'RO',
#   'Date': '2022-07-28 16:44:07'},
#  {'City': 'Rubizhne',
#   'Lat': 49.0123,
#   'Lng': 38.3797,
#   'Current Description': 'broken clouds',
#   'Max Temp': 80.6,
#   'Humidity': 42,
#   'Cloudiness': 68,
#   'Wind Speed': 6.35,
#   'Country': 'UA',
#   'Date': '2022-07-28 16:44:07'},
#  {'City': 'Tehachapi',
#   'Lat': 35.1322,
#   'Lng': -118.449,
#   'Current Description': 'few clouds',
#   'Max Temp': 88.56,
#   'Humidity': 26,
#   'Cloudiness': 16,
#   'Wind Speed': 11.01,
#   'Country': 'US',
#   'Date': '2022-07-28 16:44:08'},
#  {'City': 'Salta',
#   'Lat': -24.7859,
#   'Lng': -65.4117,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 57.79,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'AR',
#   'Date': '2022-07-28 16:43:33'},
#  {'City': 'Lazi',
#   'Lat': 48.0667,
#   'Lng': 24.2333,
#   'Current Description': 'broken clouds',
#   'Max Temp': 80.4,
#   'Humidity': 47,
#   'Cloudiness': 51,
#   'Wind Speed': 5.5,
#   'Country': 'UA',
#   'Date': '2022-07-28 16:44:09'},
#  {'City': 'Mbanza-Ngungu',
#   'Lat': -5.25,
#   'Lng': 14.8667,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 78.84,
#   'Humidity': 37,
#   'Cloudiness': 25,
#   'Wind Speed': 5.48,
#   'Country': 'CD',
#   'Date': '2022-07-28 16:44:09'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Current Description': 'few clouds',
#   'Max Temp': 45.79,
#   'Humidity': 75,
#   'Cloudiness': 14,
#   'Wind Speed': 5.7,
#   'Country': 'AU',
#   'Date': '2022-07-28 16:44:10'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 52.34,
#   'Humidity': 46,
#   'Cloudiness': 33,
#   'Wind Speed': 15.88,
#   'Country': 'AR',
#   'Date': '2022-07-28 16:40:28'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.16,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 9.86,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:44:10'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 70.18,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'MU',
#   'Date': '2022-07-28 16:45:11'},
#  {'City': 'Kamina',
#   'Lat': -8.7386,
#   'Lng': 24.9906,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 70.56,
#   'Humidity': 25,
#   'Cloudiness': 97,
#   'Wind Speed': 4.94,
#   'Country': 'CD',
#   'Date': '2022-07-28 16:45:11'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Current Description': 'clear sky',
#   'Max Temp': 64.35,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Date': '2022-07-28 16:43:27'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Current Description': 'broken clouds',
#   'Max Temp': 75.09,
#   'Humidity': 78,
#   'Cloudiness': 79,
#   'Wind Speed': 13.8,
#   'Country': 'NU',
#   'Date': '2022-07-28 16:45:12'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 69.48,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'RE',
#   'Date': '2022-07-28 16:45:13'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Current Description': 'light rain',
#   'Max Temp': 71.22,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'MU',
#   'Date': '2022-07-28 16:40:14'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 78.08,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 4.74,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:45:13'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 67.17,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 1.83,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:45:15'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Current Description': 'few clouds',
#   'Max Temp': 69.64,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:45:15'},
#  {'City': 'Lukulu',
#   'Lat': -14.3707,
#   'Lng': 23.242,
#   'Current Description': 'few clouds',
#   'Max Temp': 67.5,
#   'Humidity': 28,
#   'Cloudiness': 22,
#   'Wind Speed': 3.38,
#   'Country': 'ZM',
#   'Date': '2022-07-28 16:45:16'},
#  {'City': 'Mankono',
#   'Lat': 8.0586,
#   'Lng': -6.1897,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 80.17,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 7.43,
#   'Country': 'CI',
#   'Date': '2022-07-28 16:45:16'},
#  {'City': 'Sergeyevka',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 62.47,
#   'Humidity': 96,
#   'Cloudiness': 88,
#   'Wind Speed': 12.53,
#   'Country': 'KZ',
#   'Date': '2022-07-28 16:45:17'},
#  {'City': 'Erdenet',
#   'Lat': 49.0333,
#   'Lng': 104.0833,
#   'Current Description': 'few clouds',
#   'Max Temp': 48.29,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.37,
#   'Country': 'MN',
#   'Date': '2022-07-28 16:45:17'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 65.71,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:45:18'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 52.12,
#   'Humidity': 82,
#   'Cloudiness': 93,
#   'Wind Speed': 18.59,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:45:18'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 84.15,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:45:18'},
#  {'City': 'Beyneu',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Current Description': 'light rain',
#   'Max Temp': 75.2,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Country': 'KZ',
#   'Date': '2022-07-28 16:45:19'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Current Description': 'light rain',
#   'Max Temp': 75.9,
#   'Humidity': 79,
#   'Cloudiness': 41,
#   'Wind Speed': 24.14,
# ...
#   'Wind Speed': 10.63,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:56:51'},
#  {'City': 'Nortelandia',
#   'Lat': -14.4547,
#   'Lng': -56.8028,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 96.1,
#   'Humidity': 15,
#   'Cloudiness': 42,
#   'Wind Speed': 6.2,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:56:51'},
#  {'City': 'Aleksandrovsk-Sakhalinskiy',
#   'Lat': 50.8975,
#   'Lng': 142.1561,
#   'Current Description': 'broken clouds',
#   'Max Temp': 56.57,
#   'Humidity': 88,
#   'Cloudiness': 61,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:56:52'},
#  {'City': 'Bania',
#   'Lat': 44.8958,
#   'Lng': 22.0447,
#   'Current Description': 'light rain',
#   'Max Temp': 81.63,
#   'Humidity': 58,
#   'Cloudiness': 67,
#   'Wind Speed': 4.38,
#   'Country': 'RO',
#   'Date': '2022-07-28 16:56:52'},
#  {'City': 'Amla',
#   'Lat': 21.9333,
#   'Lng': 78.1167,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 73.85,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:56:52'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Current Description': 'clear sky',
#   'Max Temp': 81.84,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'FR',
#   'Date': '2022-07-28 16:56:53'},
#  {'City': 'Bhadrachalam',
#   'Lat': 17.6667,
#   'Lng': 80.8833,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.12,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:56:53'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 70.3,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'GB',
#   'Date': '2022-07-28 16:56:53'},
#  {'City': 'Kennett',
#   'Lat': 36.2362,
#   'Lng': -90.0556,
#   'Current Description': 'few clouds',
#   'Max Temp': 82.96,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-07-28 16:56:54'},
#  {'City': 'Corsicana',
#   'Lat': 32.0954,
#   'Lng': -96.4689,
#   'Current Description': 'clear sky',
#   'Max Temp': 94.75,
#   'Humidity': 49,
#   'Cloudiness': 2,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2022-07-28 16:56:54'},
#  {'City': 'Caucaia',
#   'Lat': -3.7361,
#   'Lng': -38.6531,
#   'Current Description': 'few clouds',
#   'Max Temp': 88.3,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:56:54'},
#  {'City': 'Mandal',
#   'Lat': 25.45,
#   'Lng': 74.5667,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.57,
#   'Humidity': 76,
#   'Cloudiness': 93,
#   'Wind Speed': 7.85,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:56:55'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Current Description': 'light rain',
#   'Max Temp': 60.1,
#   'Humidity': 96,
#   'Cloudiness': 96,
#   'Wind Speed': 0.94,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:56:55'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Current Description': 'broken clouds',
#   'Max Temp': 83.48,
#   'Humidity': 84,
#   'Cloudiness': 67,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:56:55'},
#  {'City': 'Lufilufi',
#   'Lat': -13.8745,
#   'Lng': -171.5986,
#   'Current Description': 'light rain',
#   'Max Temp': 69.58,
#   'Humidity': 78,
#   'Cloudiness': 30,
#   'Wind Speed': 19.06,
#   'Country': 'WS',
#   'Date': '2022-07-28 16:56:56'},
#  {'City': 'Luwuk',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 75.85,
#   'Humidity': 89,
#   'Cloudiness': 97,
#   'Wind Speed': 5.14,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:56:56'},
#  {'City': 'Skagen',
#   'Lat': 57.7209,
#   'Lng': 10.5839,
#   'Current Description': 'clear sky',
#   'Max Temp': 62.55,
#   'Humidity': 67,
#   'Cloudiness': 2,
#   'Wind Speed': 6.13,
#   'Country': 'DK',
#   'Date': '2022-07-28 16:56:57'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 64.38,
#   'Humidity': 52,
#   'Cloudiness': 29,
#   'Wind Speed': 14.72,
#   'Country': 'MN',
#   'Date': '2022-07-28 16:56:57'},
#  {'City': 'Linxia',
#   'Lat': 35.6003,
#   'Lng': 103.2064,
#   'Current Description': 'clear sky',
#   'Max Temp': 57.49,
#   'Humidity': 78,
#   'Cloudiness': 10,
#   'Wind Speed': 3.44,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:56:57'},
#  {'City': 'Kota Kinabalu',
#   'Lat': 5.9749,
#   'Lng': 116.0724,
#   'Current Description': 'few clouds',
#   'Max Temp': 76.98,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'MY',
#   'Date': '2022-07-28 16:56:58'},
#  {'City': 'Gwadar',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 82.17,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 7.56,
#   'Country': 'PK',
#   'Date': '2022-07-28 16:56:58'},
#  {'City': 'Yelandur',
#   'Lat': 12.0667,
#   'Lng': 77.0333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.93,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:56:58'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Current Description': 'clear sky',
#   'Max Temp': 79.43,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 2.06,
#   'Country': 'PT',
#   'Date': '2022-07-28 16:56:59'},
#  {'City': 'Minador Do Negrao',
#   'Lat': -9.3053,
#   'Lng': -36.8647,
#   'Current Description': 'broken clouds',
#   'Max Temp': 75.22,
#   'Humidity': 79,
#   'Cloudiness': 82,
#   'Wind Speed': 7.83,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:52:15'},
#  {'City': 'Pelym',
#   'Lat': 61.0108,
#   'Lng': 61.9978,
#   'Current Description': 'clear sky',
#   'Max Temp': 63.21,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 3.42,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:56:59'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 83.28,
#   'Humidity': 73,
#   'Cloudiness': 93,
#   'Wind Speed': 13.22,
#   'Country': 'MV',
#   'Date': '2022-07-28 16:57:00'},
#  {'City': 'Pontal Do Parana',
#   'Lat': -25.6533,
#   'Lng': -48.5128,
#   'Current Description': 'broken clouds',
#   'Max Temp': 87.98,
#   'Humidity': 44,
#   'Cloudiness': 57,
#   'Wind Speed': 3.53,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:57:00'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.09,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 12.59,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:57:01'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 65.44,
#   'Humidity': 63,
#   'Cloudiness': 96,
#   'Wind Speed': 4.07,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:57:01'},
#  {'City': 'Manta',
#   'Lat': -0.95,
#   'Lng': -80.7333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 74.98,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'EC',
#   'Date': '2022-07-28 16:57:01'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Current Description': 'light rain',
#   'Max Temp': 77.29,
#   'Humidity': 92,
#   'Cloudiness': 35,
#   'Wind Speed': 4.27,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:57:02'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Current Description': 'broken clouds',
#   'Max Temp': 81.1,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 10.65,
#   'Country': 'PG',
#   'Date': '2022-07-28 16:57:03'},
#  {'City': 'Mattru',
#   'Lat': 7.6244,
#   'Lng': -11.8332,
#   'Current Description': 'light rain',
#   'Max Temp': 76.24,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 6.49,
#   'Country': 'SL',
#   'Date': '2022-07-28 16:57:03'},
#  {'City': 'Mucurapo',
#   'Lat': 10.6667,
#   'Lng': -61.5333,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 89.65,
#   'Humidity': 77,
#   'Cloudiness': 43,
#   'Wind Speed': 8.01,
#   'Country': 'TT',
#   'Date': '2022-07-28 16:57:03'},
#  {'City': 'Talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Current Description': 'clear sky',
#   'Max Temp': 75.96,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'PE',
#   'Date': '2022-07-28 16:57:04'},
#  {'City': 'Millau',
#   'Lat': 44.0833,
#   'Lng': 2.9167,
#   'Current Description': 'few clouds',
#   'Max Temp': 84.33,
#   'Humidity': 30,
#   'Cloudiness': 17,
#   'Wind Speed': 7.63,
#   'Country': 'FR',
#   'Date': '2022-07-28 16:57:05'},
#  {'City': 'Toppenish',
#   'Lat': 46.3774,
#   'Lng': -120.3087,
#   'Current Description': 'clear sky',
#   'Max Temp': 94.71,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Country': 'US',
#   'Date': '2022-07-28 16:57:05'},
#  {'City': 'Kyren',
#   'Lat': 51.6828,
#   'Lng': 102.1408,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 55.35,
#   'Humidity': 90,
#   'Cloudiness': 88,
#   'Wind Speed': 1.7,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:57:06'},
#  {'City': 'Tiverton',
#   'Lat': 50.9,
#   'Lng': -3.4833,
#   'Current Description': 'few clouds',
#   'Max Temp': 70.9,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'GB',
#   'Date': '2022-07-28 16:57:06'},
#  {'City': 'Eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Current Description': 'broken clouds',
#   'Max Temp': 58.93,
#   'Humidity': 88,
#   'Cloudiness': 79,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-07-28 16:57:06'},
#  {'City': 'Ossora',
#   'Lat': 59.2353,
#   'Lng': 163.0719,
#   'Current Description': 'broken clouds',
#   'Max Temp': 48.18,
#   'Humidity': 78,
#   'Cloudiness': 71,
#   'Wind Speed': 3.44,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:57:07'},
#  {'City': 'Stokmarknes',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Current Description': 'broken clouds',
#   'Max Temp': 53.58,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:57:07'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Current Description': 'few clouds',
#   'Max Temp': 59.18,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:57:08'},
#  {'City': 'Olyka',
#   'Lat': 50.7186,
#   'Lng': 25.8125,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 71.92,
#   'Humidity': 62,
#   'Cloudiness': 91,
#   'Wind Speed': 6.38,
#   'Country': 'UA',
#   'Date': '2022-07-28 16:58:08'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 41.36,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05,
#   'Country': 'NZ',
#   'Date': '2022-07-28 16:58:09'},
#  {'City': 'Yamada',
#   'Lat': 39.4667,
#   'Lng': 141.95,
#   'Current Description': 'clear sky',
#   'Max Temp': 70.95,
#   'Humidity': 94,
#   'Cloudiness': 5,
#   'Wind Speed': 3.62,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:58:09'},
#  {'City': 'Jamsa',
#   'Lat': 61.8642,
#   'Lng': 25.19,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 62.15,
#   'Humidity': 64,
#   'Cloudiness': 94,
#   'Wind Speed': 7.81,
#   'Country': 'FI',
#   'Date': '2022-07-28 16:58:10'},
#  {'City': 'Port Arthur',
#   'Lat': 38.8,
#   'Lng': 121.2667,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 77.22,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:58:10'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 72.28,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Country': 'BR',
#   'Date': '2022-07-28 16:58:10'},
#  {'City': 'Rolla',
#   'Lat': 37.9514,
#   'Lng': -91.7713,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 88.05,
#   'Humidity': 66,
#   'Cloudiness': 39,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Date': '2022-07-28 16:55:40'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Current Description': 'few clouds',
#   'Max Temp': 63.63,
#   'Humidity': 84,
#   'Cloudiness': 11,
#   'Wind Speed': 11.03,
#   'Country': 'MG',
#   'Date': '2022-07-28 16:58:11'},
#  {'City': 'Havoysund',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 50.23,
#   'Humidity': 80,
#   'Cloudiness': 92,
#   'Wind Speed': 17.29,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:58:12'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Current Description': 'clear sky',
#   'Max Temp': 83.35,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'CN',
#   'Date': '2022-07-28 16:58:12'},
#  {'City': 'Kalanguy',
#   'Lat': 51.0167,
#   'Lng': 116.5167,
#   'Current Description': 'few clouds',
#   'Max Temp': 53.98,
#   'Humidity': 78,
#   'Cloudiness': 13,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Date': '2022-07-28 16:58:12'},
#  {'City': 'Ochakiv',
#   'Lat': 46.6128,
#   'Lng': 31.5498,
#   'Current Description': 'broken clouds',
#   'Max Temp': 78.21,
#   'Humidity': 62,
#   'Cloudiness': 78,
#   'Wind Speed': 10.36,
#   'Country': 'UA',
#   'Date': '2022-07-28 16:58:13'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 48.15,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Date': '2022-07-28 16:58:13'},
#  {'City': 'Pontianak',
#   'Lat': -0.0333,
#   'Lng': 109.3333,
#   'Current Description': 'broken clouds',
#   'Max Temp': 75.4,
#   'Humidity': 95,
#   'Cloudiness': 69,
#   'Wind Speed': 1.86,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:56:58'},
#  {'City': 'Leirvik',
#   'Lat': 59.7798,
#   'Lng': 5.5005,
#   'Current Description': 'clear sky',
#   'Max Temp': 64.85,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:58:14'},
#  {'City': 'Sigli',
#   'Lat': 5.3848,
#   'Lng': 95.9609,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 78.35,
#   'Humidity': 84,
#   'Cloudiness': 89,
#   'Wind Speed': 3.02,
#   'Country': 'ID',
#   'Date': '2022-07-28 16:58:14'},
#  {'City': 'Virginia Beach',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Current Description': 'broken clouds',
#   'Max Temp': 94.05,
#   'Humidity': 66,
#   'Cloudiness': 72,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2022-07-28 16:56:58'},
#  {'City': 'Saurikh',
#   'Lat': 27.029,
#   'Lng': 79.4896,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 88.79,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Date': '2022-07-28 16:58:15'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 79.2,
#   'Humidity': 90,
#   'Cloudiness': 95,
#   'Wind Speed': 8.61,
#   'Country': 'JP',
#   'Date': '2022-07-28 16:58:15'},
#  {'City': 'Alamosa',
#   'Lat': 37.4695,
#   'Lng': -105.87,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 70.05,
#   'Humidity': 50,
#   'Cloudiness': 92,
#   'Wind Speed': 4.76,
#   'Country': 'US',
#   'Date': '2022-07-28 16:57:39'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 69.22,
#   'Humidity': 86,
#   'Cloudiness': 87,
#   'Wind Speed': 4.5,
#   'Country': 'IT',
#   'Date': '2022-07-28 16:58:16'},
#  {'City': 'Ligayan',
#   'Lat': 4.6533,
#   'Lng': 119.4706,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 83.88,
#   'Humidity': 68,
#   'Cloudiness': 46,
#   'Wind Speed': 3.51,
#   'Country': 'PH',
#   'Date': '2022-07-28 16:58:17'},
#  {'City': 'Lindas',
#   'Lat': 60.7381,
#   'Lng': 5.16,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 66.72,
#   'Humidity': 67,
#   'Cloudiness': 28,
#   'Wind Speed': 8.34,
#   'Country': 'NO',
#   'Date': '2022-07-28 16:58:17'},
#  {'City': 'Weyburn',
#   'Lat': 49.6668,
#   'Lng': -103.8511,
#   'Current Description': 'clear sky',
#   'Max Temp': 66.42,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2022-07-28 16:58:18'},
#  {'City': 'Rock Springs',
#   'Lat': 41.5875,
#   'Lng': -109.2029,
#   'Current Description': 'clear sky',
#   'Max Temp': 79.23,
#   'Humidity': 42,
#   'Cloudiness': 9,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-07-28 16:58:18'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Current Description': 'clear sky',
#   'Max Temp': 67.1,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 6.49,
#   'Country': 'US',
#   'Date': '2022-07-28 16:58:18'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0          Hasaki  35.7333  140.8333       broken clouds     77.40        90
# 1        Tessalit  20.1986    1.0114     overcast clouds     95.56        23
# 2      Vermillion  42.7794  -96.9292           clear sky     75.36        20
# 3     Yellowknife  62.4560 -114.3525       broken clouds     64.92        68
# 4  Saint-Philippe -21.3585   55.7679           clear sky     67.21        84
# 5        Superior  46.7208  -92.1041       broken clouds     74.70        56
# 6  Port Elizabeth -33.9180   25.5701           clear sky     61.09        96
# 7        Victoria  22.2855  114.1577     overcast clouds     87.33        80
# 8            Kaeo -35.1000  173.7833       broken clouds     52.32        83
# 9       Jamestown  42.0970  -79.2353          few clouds     82.06        44
#
#    Cloudiness  Wind Speed Country                 Date
# 0          79       10.94      JP  2022-07-28 19:39:04
# 1          91       11.41      ML  2022-07-28 19:39:04
# 2           5       12.24      US  2022-07-28 19:39:04
# 3          75       10.36      CA  2022-07-28 19:37:58
# 4           4        8.86      RE  2022-07-28 19:39:05
# 5          75       13.80      US  2022-07-28 19:39:05
# 6           0        4.61      ZA  2022-07-28 19:34:46
# 7         100        4.00      HK  2022-07-28 19:39:03
# 8          54        6.04      NZ  2022-07-28 19:39:06
# 9          20       16.11      US  2022-07-28 19:36:56

# %%
# Reorder DataFrame
new_column_order = ["City","Country","Date", "Current Description","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country                 Date Current Description      Lat  \
# 0            Hasaki      JP  2022-07-28 19:39:04       broken clouds  35.7333
# 1          Tessalit      ML  2022-07-28 19:39:04     overcast clouds  20.1986
# 2        Vermillion      US  2022-07-28 19:39:04           clear sky  42.7794
# 3       Yellowknife      CA  2022-07-28 19:37:58       broken clouds  62.4560
# 4    Saint-Philippe      RE  2022-07-28 19:39:05           clear sky -21.3585
# ..              ...     ...                  ...                 ...      ...
# 715    Barra Patuca      HN  2022-07-28 19:58:24           clear sky  15.8000
# 716       Mariental      NA  2022-07-28 19:58:25    scattered clouds -24.6333
# 717          Palmer      US  2022-07-28 19:54:02       broken clouds  42.1584
# 718        Atherton      GB  2022-07-28 19:58:25     overcast clouds  53.5237
# 719           Zabol      AF  2022-07-28 19:58:26     overcast clouds  32.2500
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    140.8333     77.40        90          79       10.94
# 1      1.0114     95.56        23          91       11.41
# 2    -96.9292     75.36        20           5       12.24
# 3   -114.3525     64.92        68          75       10.36
# 4     55.7679     67.21        84           4        8.86
# ..        ...       ...       ...         ...         ...
# 715  -84.2833     85.19        64          10        8.59
# 716   17.9667     62.35        18          38       13.24
# 717  -72.3287     89.65        60          75       13.80
# 718   -2.4935     65.28        76         100        3.00
# 719   67.2500     76.44        62         100       13.94
#
# [720 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
